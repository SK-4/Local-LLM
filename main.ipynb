# %%
import nest_asyncio
from gitingest import ingest

# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

# Function to process the GitHub repository using GitIngest (synchronously)
def process_with_gitingest(github_url):
    summary, tree, content = ingest(github_url)
    return summary, tree, content

# Example usage for both 

# Example GitHub URL
github_url = "https://github.com/SK-4/Calmly"

# Step 2: Process GitHub URL with GitIngest
summary, tree, content = process_with_gitingest(github_url)
print(f"GitHub Summary: {summary}")
print(f"GitHub Tree: {tree}")
print(f"GitHub Content: {content}")
# Out:
# GitHub Summary: Repository: SK-4/Calmly
# Files analyzed: 14
#
# Estimated tokens: 7.4k
# GitHub Tree: Directory structure:
# └── SK-4-Calmly/
#     ├── requirements.txt
#     ├── .streamlit/
#     │   └── config.toml
#     ├── streamlit_app.py
#     ├── multipage/
#     │   ├── wkhtmltopdf.exe
#     │   ├── user.py
#     │   ├── .streamlit/
#     │   │   └── config.toml
#     │   ├── __pycache__/
#     │   ├── pages/
#     │   │   ├── invoice_template.html
#     │   │   ├── doctor.py
#     │   │   └── invoice.py
#     │   └── wkhtmltoimage.exe
#     ├── README.md
#     ├── mcq.py
#     ├── streamlit-music.py
#     └── data.txt
#
# GitHub Content: ================================================
# File: /.streamlit/config.toml
# ...
# [theme]
# primaryColor="#f70000"
# backgroundColor="#dac3c3"
# secondaryBackgroundColor="#959dde"
# textColor="#000000"
# font="monospace"
#
#
# ...
# File: /streamlit_app.py
# ...
# import streamlit as st
# from streamlit_chat import message as st_message
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3.2")

chain = prompt | model

chain.invoke({"question": "What is LangChain?"})
# Out:
# 'LangChain is an open-source framework that aims to simplify the development of blockchain-based applications. It provides a set of reusable, modular components that can be used to build scalable and secure blockchain applications.\n\nThink of LangChain as a "blockchain builder\'s kit." It includes tools for handling data interactions between different blockchain platforms, as well as for integrating with external services like APIs and databases. This allows developers to focus on building the logic of their application rather than worrying about the underlying blockchain infrastructure.\n\nLangChain is built on top of several popular blockchain protocols, including Ethereum, Solana, and Cosmos. It provides a unified API that can be used to interact with these different protocols, making it easier for developers to build cross-chain applications.\n\nSo, in short, LangChain is a tool designed to make it easier for developers to build blockchain-based applications by providing a set o
# ...
